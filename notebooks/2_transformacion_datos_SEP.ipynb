# %%
# !which python
# Out:
# /Users/brayan/jupyter-env/bin/python

# %%
# !pip install pandas numpy matplotlib seaborn
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp39-cp39-macosx_10_9_x86_64.whl.metadata (91 kB)
# Collecting numpy
#   Downloading numpy-2.0.2-cp39-cp39-macosx_10_9_x86_64.whl.metadata (60 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-macosx_10_12_x86_64.whl.metadata (11 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/brayan/jupyter-env/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_10_9_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/brayan/jupyter-env/lib/python3.9/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp39-cp39-macosx_10_10_x86_64.whl.metadata (9.0 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/brayan/jupyter-env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Users/brayan/jupyter-env/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp39-cp39-macosx_10_9_x86_64.whl (11.6 MB)
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/11.6 MB 2.6 MB/s eta 0:00:04
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (1.8 MB/11.6 MB, attempt 1)
# Resuming download pandas-2.3.3-cp39-cp39-macosx_10_9_x86_64.whl (1.8 MB/11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 220.8 kB/s  0:00:37 eta 0:00:02
# Downloading numpy-2.0.2-cp39-cp39-macosx_10_9_x86_64.whl (21.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.2/21.2 MB 380.8 kB/s  0:00:51m0:00:0100:02
# Downloading matplotlib-3.9.4-cp39-cp39-macosx_10_12_x86_64.whl (7.9 MB)
#    ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/7.9 MB 203.7 kB/s eta 0:00:37
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (524 kB/7.9 MB, attempt 1)
# Resuming download matplotlib-3.9.4-cp39-cp39-macosx_10_12_x86_64.whl (524 kB/7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 237.6 kB/s  0:00:30 eta 0:00:02
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl (265 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp39-cp39-macosx_10_9_x86_64.whl (2.3 MB)
#    ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/2.3 MB ? eta -:--:--
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (262 kB/2.3 MB, attempt 1)
# Resuming download fonttools-4.60.1-cp39-cp39-macosx_10_9_x86_64.whl (262 kB/2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 154.2 kB/s  0:00:13 eta 0:00:02
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading kiwisolver-1.4.7-cp39-cp39-macosx_10_9_x86_64.whl (65 kB)
# Downloading pillow-11.3.0-cp39-cp39-macosx_10_10_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 297.0 kB/s  0:00:17m0:00:0100:02
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pyparsing, pillow, numpy, kiwisolver, importlib-resources, fonttools, cycler, pandas, contourpy, matplotlib, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [seaborn]2/13 [seaborn]ib]
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.60.1 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 numpy-2.0.2 pandas-2.3.3 pillow-11.3.0 pyparsing-3.2.5 pytz-2025.2 seaborn-0.13.2 tzdata-2025.2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
diccionario = pd.read_excel('diccionario_formato_911.xlsx')

# %%
diccionario.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NOMBRE       156 non-null    object
#  1   DESCRIPCION  156 non-null    object
# dtypes: object(2)
# memory usage: 2.6+ KB

# %%
diccionario.head(10)
# Out:
#         NOMBRE                      DESCRIPCION
# 0      ENTIDAD              CLAVE DE LA ENTIDAD
# 1    N_ENTIDAD             NOMBRE DE LA ENTIDAD
# 2    MUNICIPIO              CLAVE DEL MUNICIPIO
# 3   N_MUNICIPI             NOMBRE DEL MUNICIPIO
# 4    LOCALIDAD            CLAVE DE LA LOCALIDAD
# 5  N_LOCALIDAD           NOMBRE DE LA LOCALIDAD
# 6    DOMICILIO  DIRECCION DEL CENTRO DE TRABAJO
# 7     CLAVECCT                    CLAVE DEL CCT
# 8        N_CCT                   NOMBRE DEL CCT
# 9        TURNO                  CLAVE DEL TURNO

# %%
datos_2019_2020 = pd.read_csv('formato_911_basica_2019-2020.csv')

# %%
import pandas as pd

# Specify the path to your Excel file
excel_file_path = 'your_excel_file.xlsx'

# Create an ExcelFile object
xls = pd.ExcelFile(excel_file_path)

# Access the sheet_names attribute to get a list of all sheet names
sheet_names_list = xls.sheet_names

# Print the list of sheet names
print(sheet_names_list)

# %%
datos_2019_2020.head()
# Out:
#    entidad       n_entidad  municipio                 n_municipi  localidad  \
# 0        1  AGUASCALIENTES          3                   CALVILLO         33
# 1        1  AGUASCALIENTES          1             AGUASCALIENTES       1097
# 2        1  AGUASCALIENTES          6        PABELLÓN DE ARTEAGA         10
# 3        1  AGUASCALIENTES          1             AGUASCALIENTES       1025
# 4        1  AGUASCALIENTES         11  SAN FRANCISCO DE LOS ROMO         84
#
#                              n_localidad                  domicilio  \
# 0                     JALTICHE DE ARRIBA      CALLE RINCON DE ROMOS
# 1  HACIENDA SAN MARCOS [FRACCIONAMIENTO]      AVENIDA DE LAS PRESAS
# 2                            EL GARABATO  CALLE VENUSTIANO CARRANZA
# 3                                POCITOS        AVENIDA JESUS MARIA
# 4                           EL CHAPARRAL            NINGUNO NINGUNO
#
#      clavecct                            n_cct  turno  ... doc_1 doc_2 doc_3  \
# 0  01DPR0270P        SOR JUANA INES DE LA CRUZ      1  ...     0     0     1
# 1  01DPR0733G  RAFAEL FRANCISCO AGUILAR LOMELÍ      1  ...     2     1     1
# 2  01DPR0175L                 SALVADOR LUEVANO      1  ...     0     0     0
# 3  01DTV0067C      ETV NUM. 67 MIGUEL BARRAGAN      1  ...     3     3     2
# 4  01KJN0308E           PREESCOLAR COMUNITARIO      1  ...     0     0     0
#
#   doc_4 doc_5 doc_6 doc_mg doc_tot  tipo_org_docente         tipo_org_alumnos
# 0     0     0     1      2       4        MULTIGRADO               INCOMPLETA
# 1     1     1     1      0       7    COMPLEMENTARIA                 COMPLETA
# 2     0     0     0      2       2        MULTIGRADO               INCOMPLETA
# 3     0     0     0      0       8    COMPLEMENTARIA  NO APLICA EN ESTE NIVEL
# 4     0     0     0      1       1        MULTIGRADO               INCOMPLETA
#
# [5 rows x 156 columns]

# %%
for i in range(19,25,1):
    print(f'formato_911_basica_20{i}-20{i+1}.csv')
#datos_2019_2020 = pd.read_csv(f'formato_911_basica_20{i}-20{i+1}.csv')
# Out:
# formato_911_basica_2019-2020.csv
# formato_911_basica_2020-2021.csv
# formato_911_basica_2021-2022.csv
# formato_911_basica_2022-2023.csv
# formato_911_basica_2023-2024.csv
# formato_911_basica_2024-2025.csv

# %%
import pandas as pd
import glob
import os

# %%
csv_files = sorted(glob.glob("formato_911_basica_*.csv"))
csv_files
# Out:
# ['formato_911_basica_2019-2020.csv',
#  'formato_911_basica_2020-2021.csv',
#  'formato_911_basica_2021-2022.csv',
#  'formato_911_basica_2022-2023.csv',
#  'formato_911_basica_2023-2024.csv',
#  'formato_911_basica_2024-2025.csv']

# %%
dataframes = {}

for file in csv_files:
    # Extraer el nombre del archivo sin extensión
    year = os.path.splitext(os.path.basename(file))[0].replace("formato_911_basica_", "")
    
    # Leer el CSV
    df = pd.read_csv(file)
    
    # Guardar en el diccionario
    dataframes[year] = df

# Ejemplo de acceso
dataframes["2022-2023"].head()
# Out:
#    entidad       n_entidad  municipio                 n_municipi  localidad  \
# 0        1  AGUASCALIENTES          1             AGUASCALIENTES          1
# 1        1  AGUASCALIENTES          1             AGUASCALIENTES          1
# 2        1  AGUASCALIENTES          2                   ASIENTOS         19
# 3        1  AGUASCALIENTES         11  SAN FRANCISCO DE LOS ROMO          1
# 4        1  AGUASCALIENTES          1             AGUASCALIENTES          1
#
#                  n_localidad               domicilio    clavecct  \
# 0             AGUASCALIENTES  CALLE GENERAL BARRAGAN  01PJN0097M
# 1             AGUASCALIENTES       AVENIDA DEL VALLE  01PPR0161N
# 2               LA ESPERANZA        CALLE CENZONTLES  01KJN0089I
# 3  SAN FRANCISCO DE LOS ROMO   CALLE 10 DE NOVIEMBRE  01DPR0017W
# 4             AGUASCALIENTES         NINGUNO NINGUNO  01EPR0001U
#
#                                                n_cct  turno  ... doc_1 doc_2  \
# 0                             COLEGIO MÉXICO MODERNO      1  ...     1     1
# 1                                     INSTITUTO CIMA      1  ...     1     1
# 2                             PREESCOLAR COMUNITARIO      1  ...     0     0
# 3                          J. REFUGIO MIRANDA AGUAYO      1  ...     2     2
# 4  CENTRO EDUCATIVO INTEGRAL PARA ALTAS CAPACIDAD...      1  ...     0     0
#
#   doc_3 doc_4 doc_5 doc_6 doc_mg doc_tot  tipo_org_docente  tipo_org_alumnos
# 0     1     0     0     0      0       3    COMPLEMENTARIA          COMPLETA
# 1     1     1     1     1      0       6    COMPLEMENTARIA          COMPLETA
# 2     0     0     0     0      1       1        MULTIGRADO        INCOMPLETA
# 3     2     2     3     2      0      13    COMPLEMENTARIA          COMPLETA
# 4     1     1     1     1      0       4    COMPLEMENTARIA        INCOMPLETA
#
# [5 rows x 156 columns]

# %%
for year, df in dataframes.items():
    print(year, df.shape)
# Out:
# 2019-2020 (230424, 156)
# 2020-2021 (228852, 156)
# 2021-2022 (228804, 156)
# 2022-2023 (229691, 156)
# 2023-2024 (231534, 156)
# 2024-2025 (231913, 156)

# %% [markdown]
# Todos los dataframes tienen 156 columnas, aunque difieren en el número de filas.

# %%
# Combinar todos los DataFrames y añadir la columna 'periodo_escolar'
combined_df = pd.concat(
    [df.assign(periodo_escolar=year) for year, df in dataframes.items()],
    ignore_index=True
)

# %%
combined_df.info()
combined_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1381218 entries, 0 to 1381217
# Columns: 313 entries, entidad to TIPO_ORG_ALUMNOS
# dtypes: float64(280), object(33)
# memory usage: 3.2+ GB
#    entidad       n_entidad  municipio                 n_municipi  localidad  \
# 0      1.0  AGUASCALIENTES        3.0                   CALVILLO       33.0
# 1      1.0  AGUASCALIENTES        1.0             AGUASCALIENTES     1097.0
# 2      1.0  AGUASCALIENTES        6.0        PABELLÓN DE ARTEAGA       10.0
# 3      1.0  AGUASCALIENTES        1.0             AGUASCALIENTES     1025.0
# 4      1.0  AGUASCALIENTES       11.0  SAN FRANCISCO DE LOS ROMO       84.0
#
#                              n_localidad                  domicilio  \
# 0                     JALTICHE DE ARRIBA      CALLE RINCON DE ROMOS
# 1  HACIENDA SAN MARCOS [FRACCIONAMIENTO]      AVENIDA DE LAS PRESAS
# 2                            EL GARABATO  CALLE VENUSTIANO CARRANZA
# 3                                POCITOS        AVENIDA JESUS MARIA
# 4                           EL CHAPARRAL            NINGUNO NINGUNO
#
#      clavecct                            n_cct  turno  ... DOC_1 DOC_2 DOC_3  \
# 0  01DPR0270P        SOR JUANA INES DE LA CRUZ    1.0  ...   NaN   NaN   NaN
# 1  01DPR0733G  RAFAEL FRANCISCO AGUILAR LOMELÍ    1.0  ...   NaN   NaN   NaN
# 2  01DPR0175L                 SALVADOR LUEVANO    1.0  ...   NaN   NaN   NaN
# 3  01DTV0067C      ETV NUM. 67 MIGUEL BARRAGAN    1.0  ...   NaN   NaN   NaN
# 4  01KJN0308E           PREESCOLAR COMUNITARIO    1.0  ...   NaN   NaN   NaN
#
#   DOC_4 DOC_5 DOC_6 DOC_MG DOC_TOT  TIPO_ORG_DOCENTE  TIPO_ORG_ALUMNOS
# 0   NaN   NaN   NaN    NaN     NaN               NaN               NaN
# 1   NaN   NaN   NaN    NaN     NaN               NaN               NaN
# 2   NaN   NaN   NaN    NaN     NaN               NaN               NaN
# 3   NaN   NaN   NaN    NaN     NaN               NaN               NaN
# 4   NaN   NaN   NaN    NaN     NaN               NaN               NaN
#
# [5 rows x 313 columns]

# %%
#Verificando los valores de la columna "periodo_escolar"
combined_df['periodo_escolar'].unique()
# Out:
# array(['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024',
#        '2024-2025'], dtype=object)

# %% [markdown]
# Ahora los 6 archivos .csv están cargados todos en un solo DataFrame, combined_df, y existe una nueva columna identificadora llamada "periodo_escolar".
